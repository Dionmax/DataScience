# %%
library(igraph)
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
grafo <- read_graph("../data/Grafo.graphml", format = "graphml")

grafo

plot(grafo)
# Out:
# IGRAPH ee32eac D-W- 53 179 --
# + attr: label (v/c), r (v/n), g (v/n), b (v/n), x (v/n), y (v/n), size
# | (v/n), Lokationposition1highest53lowest (v/n), Handicapped (v/n),
# | Repeater (v/n), Sweetsgiver (v/n), id (v/c), Edge Label (e/c), weight
# | (e/n), id (e/c)
# + edges from ee32eac:
#  [1]  1-> 4  1-> 5  1->37  2->15  2->25  2->51  3-> 2  3-> 4  3-> 9  3->16
# [11]  3->36  4->10  4->14  4->23  4->36  4->46  4->49  5-> 1  5-> 6  5->14
# [21]  5->24  6-> 2  6-> 4  6-> 5  6->14  7->11  7->16  9->41  9->50 10-> 4
# [31] 11-> 7 11-> 9 11->14 11->15 11->28 12->44 13->41 14-> 1 14->15 14->23
# [41] 14->46 15-> 5 15-> 6 15-> 7 15->14 15->17 15->23 15->25 15->46 15->51
# + ... omitted several edges
# Plot with title “”

# %%
degree(grafo, mode = "all")
# Out:
#  [1] 11  7  8 10 10  7  5  0  6  2 13  2  2 18 26  8  6  7  2  0  4 13 15  9  8
# [26]  3  2  2  3  7  6  2  4  0  1 13  4 14  5  0 15  4  4  5  9 14  3  0 13  8
# [51]  8  5  5

# %%
degree(grafo, mode = "in")
# Out:
#  [1]  8  4  3  4  6  3  3  0  4  1  8  1  1 14 17  4  5  1  2  0  3  3 11  5  5
# [26]  0  1  1  1  3  1  1  2  0  0  4  2  2  2  0 10  1  0  3  3 10  1  0  4  4
# [51]  5  1  1

# %%
degree(grafo, mode = "out")
# Out:
#  [1]  3  3  5  6  4  4  2  0  2  1  5  1  1  4  9  4  1  6  0  0  1 10  4  4  3
# [26]  3  1  1  2  4  5  1  2  0  1  9  2 12  3  0  5  3  4  2  6  4  2  0  9  4
# [51]  3  4  4

# %%
grau <- degree(grafo, mode = "in")

plot(grafo, vertex.size = grau)
# Out:
# Plot with title “”

# %%
grau <- degree(grafo, mode = "in")

hist(grau, breaks = 20, col = "blue", xlab = "Grau", ylab = "Frequência", main = "Histograma do Grau de Entrada")
# Out:
# Plot with title “Histograma do Grau de Entrada”

# %%
diameter(grafo, directed = TRUE)
# Out:
# [1] 8

# %%
diameter(grafo, directed = FALSE)
# Out:
# [1] 5

# %%
get_diameter(grafo, directed = TRUE)
# Out:
# + 9/53 vertices, from ee32eac:
# [1]  7 16  3  4 49 38 39 33 27

# %%
get_diameter(grafo, directed = FALSE)
# Out:
# + 6/53 vertices, from ee32eac:
# [1] 10  4 23 39 33 27

# %%
neighborhood(grafo, order = 0, mode = "all")
# Out:
# [[1]]
# + 1/53 vertex, from ee32eac:
# [1] 1
#
# [[2]]
# + 1/53 vertex, from ee32eac:
# [1] 2
#
# [[3]]
# + 1/53 vertex, from ee32eac:
# [1] 3
#
# [[4]]
# + 1/53 vertex, from ee32eac:
# [1] 4
#
# [[5]]
# + 1/53 vertex, from ee32eac:
# [1] 5
#
# [[6]]
# + 1/53 vertex, from ee32eac:
# [1] 6
#
# [[7]]
# + 1/53 vertex, from ee32eac:
# [1] 7
#
# [[8]]
# + 1/53 vertex, from ee32eac:
# [1] 8
#
# [[9]]
# + 1/53 vertex, from ee32eac:
# [1] 9
#
# [[10]]
# + 1/53 vertex, from ee32eac:
# [1] 10
#
# [[11]]
# + 1/53 vertex, from ee32eac:
# [1] 11
#
# [[12]]
# + 1/53 vertex, from ee32eac:
# [1] 12
#
# [[13]]
# + 1/53 vertex, from ee32eac:
# [1] 13
#
# [[14]]
# + 1/53 vertex, from ee32eac:
# [1] 14
#
# [[15]]
# + 1/53 vertex, from ee32eac:
# [1] 15
#
# [[16]]
# + 1/53 vertex, from ee32eac:
# [1] 16
#
# [[17]]
# + 1/53 vertex, from ee32eac:
# [1] 17
#
# [[18]]
# + 1/53 vertex, from ee32eac:
# [1] 18
#
# [[19]]
# + 1/53 vertex, from ee32eac:
# [1] 19
#
# [[20]]
# + 1/53 vertex, from ee32eac:
# [1] 20
# ...

# %%
edge_density(grafo, loops = FALSE)
# Out:
# [1] 0.0649492
