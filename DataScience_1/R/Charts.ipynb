# %%
trees
# Out:
#    Girth Height Volume
# 1   8.3  70     10.3
# 2   8.6  65     10.3
# 3   8.8  63     10.2
# 4  10.5  72     16.4
# 5  10.7  81     18.8
# 6  10.8  83     19.7
# 7  11.0  66     15.6
# 8  11.0  75     18.2
# 9  11.1  80     22.6
# 10 11.2  75     19.9
# 11 11.3  79     24.2
# 12 11.4  76     21.0
# 13 11.4  76     21.4
# 14 11.7  69     21.3
# 15 12.0  75     19.1
# 16 12.9  74     22.2
# 17 12.9  85     33.8
# 18 13.3  86     27.4
# 19 13.7  71     25.7
# 20 13.8  64     24.9
# 21 14.0  78     34.5
# 22 14.2  80     31.7
# 23 14.5  74     36.3
# 24 16.0  72     38.3
# 25 16.3  77     42.6
# 26 17.3  81     55.4
# 27 17.5  82     55.7
# 28 17.9  80     58.3
# 29 18.0  80     51.5
# 30 18.0  80     51.0
# 31 20.6  87     77.0

# %%
hist(trees$Height)
# Out:
# Plot with title “Histogram of trees$Height”

# %%
hist(trees$Height, main = "Trees", ylab = "Frequency", xlab = "Height", col = "blue")
# Out:
# Plot with title “Trees”

# %%
hist(trees$Height, main = "Trees", ylab = "Frequency", xlab = "Height", col = "blue", density = 20, breaks = 20)
# Out:
# Plot with title “Trees”

# %%
heightDensity <- density(trees$Height)
plot(heightDensity)
# Out:
# Plot with title “density(x = trees$Height)”

# %%
hist(trees$Height, main = NULL, xlab = NULL, ylab = NULL)
par(new = TRUE)
plot(heightDensity)
# Out:
# Plot with title “density(x = trees$Height)”

# %%
plot(trees$Girth, trees$Volume)
plot(trees$Girth, trees$Volume, main = "Trees")
plot(trees$Girth, trees$Volume, ylab = "Circumference", xlab = "Volume", main = "Trees", col = "blue")
plot(trees$Girth, trees$Volume, ylab = "Circumference", xlab = "Volume", main = "Trees", col = "blue", pch = 20)
# Out:
# plot without title
# Plot with title “Trees”
# Plot with title “Trees”
# Plot with title “Trees”

# %%
plot(trees$Girth, trees$Volume, ylab = "Circumference", xlab = "Volume", main = "Trees", col = "blue", pch = 20, type = "l")
# Out:
# Plot with title “Trees”

# %%
plot(jitter(trees$Girth), trees$Volume, ylab = "Circumference", xlab = "Volume", main = "Trees", col = "blue")
# Out:
# Plot with title “Trees”

# %%
head(CO2)
# Out:
#   Plant Type   Treatment  conc uptake
# 1 Qn1   Quebec nonchilled  95  16.0
# 2 Qn1   Quebec nonchilled 175  30.4
# 3 Qn1   Quebec nonchilled 250  34.8
# 4 Qn1   Quebec nonchilled 350  37.2
# 5 Qn1   Quebec nonchilled 500  35.3
# 6 Qn1   Quebec nonchilled 675  39.2

# %%
plot(CO2$conc, CO2$uptake, pch = 20, col = CO2$Treatment)
legend("bottomright", legend = c("nonchilled", "chilled"), cex = 1, fill = c("black", "red"))
# Out:
# plot without title

# %%
plot(trees)
# Out:
# plot without title

# %%
split.screen(figs = c(2, 2))
screen(1)
plot(trees$Girth, trees$Volume)
screen(2)
plot(trees$Girth, trees$Height)
screen(3)
plot(trees$Height, trees$Volume)
screen(4)
hist(trees$Volume)
close.screen(all = TRUE)
# Out:
# [1] 1 2 3 4
# Plot with title “Histogram of trees$Volume”

# %%
boxplot(trees$Volume, main = "Volume of Trees", ylab = "Volume")
boxplot(trees$Volume, main = "Volume of Trees", ylab = "Volume", col = "blue", horizontal = TRUE)
boxplot(trees$Volume, main = "Volume of Trees", ylab = "Volume", col = "blue", outline = FALSE)
# Out:
# Plot with title “Volume of Trees”
# Plot with title “Volume of Trees”
# Plot with title “Volume of Trees”

# %%
boxplot(trees$Height, main = "Tree Height", xlab = "Height", col = "blue", notch = TRUE)
# Out:
# Plot with title “Tree Height”

# %%
boxplot.stats(trees$Height)
# Out:
# $stats
# [1] 63 72 76 80 87
#
# $n
# [1] 31
#
# $conf
# [1] 73.72979 78.27021
#
# $out
# numeric(0)

# %%
boxplot.stats(trees$Height)$stats
# Out:
# [1] 63 72 76 80 87

# %%
boxplot(trees)
# Out:
# plot without title

# %%
InsectSprays
# Out:
#    count spray
# 1  10    A
# 2   7    A
# 3  20    A
# 4  14    A
# 5  14    A
# 6  12    A
# 7  10    A
# 8  23    A
# 9  17    A
# 10 20    A
# 11 14    A
# 12 13    A
# 13 11    B
# 14 17    B
# 15 21    B
# 16 11    B
# 17 16    B
# 18 14    B
# 19 17    B
# 20 17    B
# 21 19    B
# 22 21    B
# 23  7    B
# 24 13    B
# 25  0    C
# 26  1    C
# 27  7    C
# 28  2    C
# 29  3    C
# 30  1    C
# ⋮  ⋮     ⋮
# 43  5    D
# 44  5    D
# 45  5    D
# 46  5    D
# 47  2    D
# 48  4    D
# 49  3    E
# 50  5    E
# 51  3    E
# 52  5    E
# 53  3    E
# 54  6    E
# 55  1    E
# 56  1    E
# 57  3    E
# 58  2    E
# 59  6    E
# 60  4    E
# 61 11    F
# 62  9    F
# 63 15    F
# 64 22    F
# 65 15    F
# 66 16    F
# 67 13    F
# 68 10    F
# 69 26    F
# 70 26    F
# 71 24    F
# 72 13    F

# %%
InsectSpraysSprays <- aggregate(. ~ spray, data = InsectSprays, sum)

InsectSpraysSprays
# Out:
#   spray count
# 1 A     174
# 2 B     184
# 3 C      25
# 4 D      59
# 5 E      42
# 6 F     200

# %%
barplot(InsectSpraysSprays$count, col = gray.colors(6), xlab = "Spray", ylab = "Total", names.arg = InsectSpraysSprays$spray)
box()
# Out:
# plot without title

# %%
# pie(InsectSpraysSprays$count, labels = InsectSpraysSprays$spray, main = "Spray Distribution", col = c(1:6))
pie(InsectSpraysSprays$count, labels = NA, main = "Spray Distribution", col = c(1:6))
legend("bottomright", legend = InsectSpraysSprays$spray, cex = 1, fill = c(1:6))
# Out:
# Plot with title “Spray Distribution”
