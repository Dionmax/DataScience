# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# pip install pyclustertend==1.4.9
from pyclustertend import (
    hopkins,
    vat,
    ivat,
    assess_tendency_by_metric,
    assess_tendency_by_mean_metric_score
)

# %%
iris = datasets.load_iris()

clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150, 4))

# %%
inertia = []

for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto')
    kmeans.fit(clust1)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
inertia = []

for i in range(1, 8):
    kmeans = KMeans(n_clusters=i, n_init='auto')
    kmeans.fit(clust2)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 8), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
hopkins(clust1, 150)
# Out:
# 0.1860059544211211

# %%
hopkins(clust2, 150)
# Out:
# 0.5051124666651006

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
m = assess_tendency_by_metric(clust1, metric='silhouette', n_cluster=3)

print(m)
# Out:
# (2, array([0.58175005, 0.45663381]))

# %%
m = assess_tendency_by_metric(clust1, metric='davies_bouldin', n_cluster=3)

print(m)
# Out:
# (2, array([0.59331269, 0.8275118 ]))

# %%
m = assess_tendency_by_metric(clust1, metric='calinski_harabasz' , n_cluster=3)

print(m)
# Out:
# (2, array([251.34933946, 241.42632349]))

# %%
m = assess_tendency_by_metric(clust2, metric='silhouette', n_cluster=3)

print(m)
# Out:
# (2, array([0.17845442, 0.17545157]))

# %%
m = assess_tendency_by_metric(clust2, metric='davies_bouldin', n_cluster=3)

print(m)
# Out:
# (3, array([2.00729833, 1.68575768]))

# %%
m = assess_tendency_by_metric(clust2, metric='calinski_harabasz' , n_cluster=3)

print(m)
# Out:
# (2, array([40.9266349 , 34.74745416]))

# %%
m = assess_tendency_by_mean_metric_score(clust1, n_cluster=3)

print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2, n_cluster=3)

print(m)
# Out:
# 2.6666666666666665
