# %%
library(lattice)

# %%
bwplot(trees$Volume, main="Trees", xlab="Volume")
# Out:
# plot without title

# %%
histogram(trees$Volume, main = "Trees", xlab = "Volume", aspect = 0.8, type = "percent", nint = 20)
# Out:
# plot without title

# %%
head(chickwts, 10)
# Out:
#    weight feed
# 1  179    horsebean
# 2  160    horsebean
# 3  136    horsebean
# 4  227    horsebean
# 5  217    horsebean
# 6  168    horsebean
# 7  108    horsebean
# 8  124    horsebean
# 9  143    horsebean
# 10 140    horsebean

# %%
histogram(chickwts$weight)
# Out:
# plot without title

# %%
aggregate(chickwts$weight, by = list(chickwts$feed), FUN = sum)
# Out:
#   Group.1   x
# 1 casein    3883
# 2 horsebean 1602
# 3 linseed   2625
# 4 meatmeal  3046
# 5 soybean   3450
# 6 sunflower 3947

# %%
histogram(~weight | feed, data = chickwts)
# Out:
# plot without title

# %%
xyplot(CO2$conc ~ CO2$uptake, main = "CO2", xlab = "Uptake", ylab = "Concentration")
# Out:
# plot without title

# %%
xyplot(CO2$conc ~ CO2$uptake | CO2$Type, main = "CO2", xlab = "Uptake", ylab = "Concentration")
# Out:
# plot without title

# %%
xyplot(CO2$conc ~ CO2$uptake | CO2$Treatment, main = "CO2", xlab = "Uptake", ylab = "Concentration")
# Out:
# plot without title

# %%
head(esoph, 10)
# Out:
#    agegp alcgp     tobgp    ncases ncontrols
# 1  25-34 0-39g/day 0-9g/day 0      40
# 2  25-34 0-39g/day 10-19    0      10
# 3  25-34 0-39g/day 20-29    0       6
# 4  25-34 0-39g/day 30+      0       5
# 5  25-34 40-79     0-9g/day 0      27
# 6  25-34 40-79     10-19    0       7
# 7  25-34 40-79     20-29    0       4
# 8  25-34 40-79     30+      0       7
# 9  25-34 80-119    0-9g/day 0       2
# 10 25-34 80-119    10-19    0       1

# %%
dotplot(esoph$alcgp ~ esoph$ncontrols, data = esoph, main = "Esophagus", xlab = "Number of Controls", ylab = "Alcohol Group")
# Out:
# plot without title

# %%
dotplot(esoph$alcgp ~ esoph$ncontrols | esoph$tobgp, data = esoph, main = "Esophagus", xlab = "Number of Controls", ylab = "Alcohol Group")
# Out:
# plot without title

# %%
splom(~ CO2[4:5] | CO2$Type, data = CO2, main = "CO2")
# Out:
# plot without title

# %%
densityplot(~CO2$conc | CO2$Treatment, main = "CO2", xlab = "Concentration", plot.points = FALSE)
# Out:
# plot without title

# %%
densityplot(~CO2$conc)
# Out:
# plot without title

# %%
densityplot(~CO2$conc | CO2$Treatment, main = "CO2", xlab = "Concentration")
# Out:
# plot without title

# %%
head(OrchardSprays, 10)
# Out:
#    decrease rowpos colpos treatment
# 1  57       1      1      D
# 2  95       2      1      E
# 3   8       3      1      B
# 4  69       4      1      H
# 5  92       5      1      G
# 6  90       6      1      F
# 7  15       7      1      C
# 8   2       8      1      A
# 9  84       1      2      C
# 10  6       2      2      B

# %%
cloud(decrease ~ rowpos * colpos, data = OrchardSprays, main = "Orchard Sprays", xlab = "Row Position", ylab = "Column Position", zlab = "Decrease")
# Out:
# plot without title

# %%
cloud(decrease ~ rowpos * colpos, data = OrchardSprays, groups=treatment, main = "Orchard Sprays", xlab = "Row Position", ylab = "Column Position", zlab = "Decrease")
# Out:
# plot without title

# %%
levelplot(Girth ~ Height * Volume, data=trees, main="Trees", xlab="Height", ylab="Volume")
# Out:
# plot without title
