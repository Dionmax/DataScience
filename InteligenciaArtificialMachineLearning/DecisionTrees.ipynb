# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
)

import graphviz

# %%
base = pd.read_csv("data/insurance.csv")

base.head()
# Out:
#    Unnamed: 0  GoodStudent         Age    SocioEcon RiskAversion VehicleYear  \
# 0           1        False       Adult        Prole  Adventurous       Older
# 1           2        False      Senior        Prole     Cautious     Current
# 2           3        False      Senior  UpperMiddle   Psychopath     Current
# 3           4        False  Adolescent       Middle       Normal       Older
# 4           5        False  Adolescent        Prole       Normal       Older
#
#   ThisCarDam RuggedAuto  Accident    MakeModel  ... HomeBase AntiTheft  \
# 0   Moderate   EggShell      Mild      Economy  ...     City     False
# 1        NaN   Football       NaN      Economy  ...     City      True
# 2        NaN   Football       NaN  FamilySedan  ...     City     False
# 3        NaN   EggShell       NaN      Economy  ...   Suburb     False
# 4   Moderate   Football  Moderate      Economy  ...     City     False
#
# ...

# %%
base.drop(columns=["Unnamed: 0"], inplace=True)

base.head()
# Out:
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current        NaN
# 2        False      Senior  UpperMiddle   Psychopath     Current        NaN
# 3        False  Adolescent       Middle       Normal       Older        NaN
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football       NaN      Economy      Normal  ...     City       True
# 2   Football       NaN  FamilySedan   Excellent  ...     City      False
# 3   EggShell       NaN      Economy      Normal  ...   Suburb      False
# 4   Football  Moderate      Economy        Poor  ...     City      False
#
# ...

# %%
base.dropna(inplace=True)

# %%
y = base.iloc[:, 7].values

X = pd.concat([base.iloc[:, 0:6], base.iloc[:, 8:]], axis=1)

X = X.values

# %%
labelEncoder = LabelEncoder()

# %%
for i in range(0, X.shape[1]):
    if X[:, i].dtype == "object":
        X[:, i] = labelEncoder.fit_transform(X[:, i])

# %%
# X independent variables
# y dependent variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
modelo = DecisionTreeClassifier(random_state=1) # 79%
modelo = DecisionTreeClassifier(random_state=1, max_depth=8) # 84%
modelo = DecisionTreeClassifier(random_state=1, max_depth=8, max_leaf_nodes=8) # 86%

modelo.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, max_leaf_nodes=8, random_state=1)

# %%
previsao = modelo.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, previsao))
print("Precision: ", precision_score(y_test, previsao, average="micro"))
print("Recall: ", recall_score(y_test, previsao, average="micro"))
print("F1: ", f1_score(y_test, previsao, average="micro"))
# Out:
# Accuracy:  0.868421052631579
# Precision:  0.868421052631579
# Recall:  0.868421052631579
# F1:  0.868421052631579

# %%
print(classification_report(y_test, previsao))
# Out:
#               precision    recall  f1-score   support
#
#         Mild       0.95      0.89      0.92       423
#     Moderate       0.81      0.76      0.78       497
#       Severe       0.87      0.93      0.90       676
#
#     accuracy                           0.87      1596
#    macro avg       0.87      0.86      0.87      1596
# weighted avg       0.87      0.87      0.87      1596

# %%
# Huge files, be careful

# dot_data = export_graphviz(modelo, out_file=None, filled=True, class_names=True, rounded=True)

# graph = graphviz.Source(dot_data)

# graph.render("Decision Tree", format="png")
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.871625 to fit
# 'Decision Tree.png'
