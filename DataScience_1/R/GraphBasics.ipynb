# %%
# install.packages("igraph")
library(igraph)
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
grafo1 <- graph(edges = c(1, 2, 3, 4))
plot(grafo1)
# Out:
# Plot with title “”

# %%
grafo2 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1))
plot(grafo2)
# Out:
# Plot with title “”

# %%
grafo3 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1, 1, 4, 4, 3, 3, 2, 2, 1))
plot(grafo3)
# Out:
# Plot with title “”

# %%
grafo4 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1, 1, 4, 4, 3, 3, 2, 2, 1, 1, 3, 3, 1))
plot(grafo4)
# Out:
# Plot with title “”

# %%
grafo5 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1, 1, 4, 4, 3, 3, 2, 2, 1, 1, 3, 3, 1, 1, 5, 5, 2, 2, 5, 5, 3, 3, 5, 5, 4, 4, 5, 5, 1, 1, 1))
plot(grafo5)
# Out:
# Plot with title “”

# %%
grafo6 <- graph_from_literal(1 - +2, 2 - +3, 3 + +4, 4 + -1)
plot(grafo6)
# Out:
# Plot with title “”

# %%
grafo6
# Out:
# IGRAPH 018a1e2 DN-- 4 5 --
# + attr: name (v/c)
# + edges from 018a1e2 (vertex names):
# [1] 1->2 1->4 2->3 3->4 4->3

# %%
grafo7 <- graph_from_literal(1 - 2, 2 - 3, 3 - 4, 4 - 1, 1 - 4, 4 - 3, 3 - 2, 2 - 1)
plot(grafo7)
# Out:
# Plot with title “”

# %%
grafo8 <- graph_from_literal(1 - 2 - 3 - 4 - 1, 5)
plot(grafo8)
# Out:
# Plot with title “”

# %%
grafo8
# Out:
# IGRAPH 8fde8d3 UN-- 5 4 --
# + attr: name (v/c)
# + edges from 8fde8d3 (vertex names):
# [1] 1--2 1--4 2--3 3--4

# %%
grafo9 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1), directed = FALSE)
plot(grafo9)
# Out:
# Plot with title “”

# %%
grafo9
# Out:
# IGRAPH 5f43541 U--- 4 4 --
# + edges from 5f43541:
# [1] 1--2 2--3 3--4 1--4

# %%
grafo10 <- graph(edges = c("A", "B", "B", "C", "C", "D", "D", "A"))
plot(grafo10)
# Out:
# Plot with title “”

# %%
grafo11 <- graph(edges = c(1, 2, 2, 3, 3, 4, 4, 1), directed = FALSE, n = 10)
plot(grafo11)
# Out:
# Plot with title “”

# %%
grafo12 <- graph(edges = c("A", "B", "B", "C", "C", "D", "D", "A"), isolates = c("E", "F", "G"))
plot(grafo12)
# Out:
# Plot with title “”

# %%
grafo13 <- graph(edges = c("Fernando", "Pedro", "José", "Antônio", "Fernando", "José", "Fernando", "Antônio"))
# pesos aos vértices como atributo
V(grafo13)$Peso <- c(40, 30, 30, 25)
# ler atributos, temos name e peso. Nome é padrão
vertex_attr(grafo13)
# atributos para arestas
E(grafo13)$TipoAmizade <- c("Amigo", "Inimigo", "Inimigo", "Amigo")
# mostra todos
edge_attr(grafo13)
# mostra atributo pelo nome
edge_attr(grafo13)$TipoAmizade
vertex_attr(grafo13)$Peso
# weight é atributo padrão
E(grafo13)$weight <- c(1, 2, 1, 3)
grafo13
# Tipo do grafo, agora temos os 4 simbolos preenchidos
V(grafo13)$type <- "Humanos"
grafo13

plot(grafo13)
# Out:
# $name
# [1] "Fernando" "Pedro"    "José"     "Antônio"
#
# $Peso
# [1] 40 30 30 25
# $TipoAmizade
# [1] "Amigo"   "Inimigo" "Inimigo" "Amigo"
# [1] "Amigo"   "Inimigo" "Inimigo" "Amigo"
# [1] 40 30 30 25
# IGRAPH 50b2e5e DNW- 4 4 --
# + attr: name (v/c), Peso (v/n), TipoAmizade (e/c), weight (e/n)
# + edges from 50b2e5e (vertex names):
# [1] Fernando->Pedro   José    ->Antônio Fernando->José    Fernando->Antônio
# IGRAPH 50b2e5e DNWB 4 4 --
# + attr: name (v/c), Peso (v/n), type (v/c), TipoAmizade (e/c), weight
# | (e/n)
# + edges from 50b2e5e (vertex names):
# [1] Fernando->Pedro   José    ->Antônio Fernando->José    Fernando->Antônio
# Plot with title “”

# %%
grafo13[]
# Out:
# 4 x 4 sparse Matrix of class "dgCMatrix"
#          Fernando Pedro José Antônio
# Fernando        .     1    1       3
# Pedro           .     .    .       .
# José            .     .    .       2
# Antônio         .     .    .       .

# %%
V(grafo13)$name
# Out:
# [1] "Fernando" "Pedro"    "José"     "Antônio"

# %%
E(grafo13)$TipoAmizade
# Out:
# [1] "Amigo"   "Inimigo" "Inimigo" "Amigo"
